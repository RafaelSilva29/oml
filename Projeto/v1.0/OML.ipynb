# %%
run one_vs_all.py
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# ########## Results OneVsAll ##########
#
# Score OneVsAll: 95.71429%
# Time OneVsAll: 0.31592s

# %%
run one_vs_one.py
# Out:
# ########## Results OneVsOne ##########
#
# Score OneVsOne: 95.71429%
# Time OneVsOne: 0.28819s

# %%
run error_correcting_output_code.py
# Out:
# ########## Results (Error-Correcting) Output-Code ##########
#
# Score (Error-Correcting) Output-Code: 95.00000%
# Time (Error-Correcting) Output-Code: 0.27063s
